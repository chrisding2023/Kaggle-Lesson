# %%
import pandas as pd
df = pd.read_csv('iris.data.txt')
df.columns=['sepal_len', 'sepal_wid', 'petal_len', 'petal_wid', 'class']
df.shape
# Out:
# (149, 5)

# %%
df.head()
# Out:
#    sepal_len  sepal_wid  petal_len  petal_wid        class
# 0        4.9        3.0        1.4        0.2  Iris-setosa
# 1        4.7        3.2        1.3        0.2  Iris-setosa
# 2        4.6        3.1        1.5        0.2  Iris-setosa
# 3        5.0        3.6        1.4        0.2  Iris-setosa
# 4        5.4        3.9        1.7        0.4  Iris-setosa

# %%
X = df[['sepal_len','sepal_wid','petal_len','petal_wid']]

# %%
X.corr()
# Out:
#            sepal_len  sepal_wid  petal_len  petal_wid
# sepal_len   1.000000  -0.103784   0.871283   0.816971
# sepal_wid  -0.103784   1.000000  -0.415218  -0.350733
# petal_len   0.871283  -0.415218   1.000000   0.962314
# petal_wid   0.816971  -0.350733   0.962314   1.000000

# %%
X.describe()
# Out:
#         sepal_len   sepal_wid   petal_len   petal_wid
# count  149.000000  149.000000  149.000000  149.000000
# mean     5.848322    3.051007    3.774497    1.205369
# std      0.828594    0.433499    1.759651    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
# compute covariance matrix
import numpy as np
mean_vec = np.mean(X, axis=0)
cov_mat = (X - mean_vec).T.dot((X - mean_vec)) / (X.shape[0]-1)
print('Covariance matrix \n%s' %cov_mat)
# Out:
# Covariance matrix
#            sepal_len  sepal_wid  petal_len  petal_wid
# sepal_len   0.686568  -0.037279   1.270362   0.515347
# sepal_wid  -0.037279   0.187921  -0.316731  -0.115749
# petal_len   1.270362  -0.316731   3.096372   1.289124
# petal_wid   0.515347  -0.115749   1.289124   0.579566

# %%
# engenvector and engienvalues
cov_mat = np.cov(X.T)

print('Covariance matrix \n%s' %cov_mat)

eig_vals, eig_vecs = np.linalg.eig(cov_mat)

print('Eigenvectors \n%s' %eig_vecs)
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Covariance matrix
# [[ 0.68656811 -0.0372787   1.27036233  0.51534691]
#  [-0.0372787   0.18792128 -0.31673091 -0.11574868]
#  [ 1.27036233 -0.31673091  3.09637221  1.28912434]
#  [ 0.51534691 -0.11574868  1.28912434  0.57956557]]
# Eigenvectors
# [[ 0.36263433 -0.6558202  -0.58115529  0.3172613 ]
#  [-0.08122848 -0.73001455  0.59619427 -0.32408808]
#  [ 0.85629752  0.17703033  0.07265649 -0.47972477]
#  [ 0.35868209  0.07509244  0.54911925  0.75111672]]
#
# Eigenvalues
# [4.20438706 0.24314579 0.07905128 0.02384304]

# %%
from sklearn.decomposition import PCA
pca = PCA()  
pca.fit(X)    
EV_List = pca.explained_variance_  
EV_List # eigenvalues
# Out:
# array([4.20438706, 0.24314579, 0.07905128, 0.02384304])

# %%
EVR_List = [i/sum(EV_List) for i in EV_List]
EVR_List # percent of explained variance
# Out:
# [0.9239543681440451,
#  0.053433619322753645,
#  0.017372275759703706,
#  0.005239736773497557]

# %%
# explain 90% variance, need 1 principal component (pc1)
pca = PCA(n_components=1)
pca.fit(X)
# Out:
# PCA(n_components=1)

# %%
# loading factors at each principal component (pc1)
pca.components_
# Out:
# array([[ 0.36263433, -0.08122848,  0.85629752,  0.35868209]])

# %%
pca.explained_variance_
# Out:
# array([4.20438706])

# %%
# Apply PCA to the data set
data_pca = pca.transform(X)
data_pca
# Out:
# array([[-2.73363445],
#        [-2.90803676],
#        [-2.76491784],
#        [-2.7461081 ],
#        [-2.29679724],
#        [-2.83904793],
#        [-2.64423265],
#        [-2.90682876],
#        [-2.69199575],
#        [-2.52354747],
#        [-2.63112977],
#        [-2.80576609],
#        [-3.24397251],
#        [-2.65975154],
#        [-2.39988069],
#        [-2.63931625],
#        [-2.66585361],
#        [-2.21575231],
#        [-2.6045924 ],
#        [-2.32791942],
#        [-2.56060135],
#        [-3.23368084],
#        [-2.32098224],
#        [-2.37424051],
#        [-2.52611151],
#        [-2.48686648],
#        [-2.57982864],
#        [-2.65733554],
#        [-2.6511475 ],
#        [-2.60676122],
#        [-2.42744251],
#        [-2.66443393],
#        [-2.61352803],
#        [-2.69199575],
#        [-2.88487621],
#        [-2.64229784],
#        [-2.69199575],
#        [-3.00058136],
#        [-2.60796922],
#        [-2.7877468 ],
#        [-2.87158978],
#        [-3.01682706],
#        [-2.42325291],
#        [-2.22620519],
#        [-2.73402967],
#        [-2.55483086],
#        [-2.85867044],
#        [-2.5598109 ],
#        [-2.72173956],
#        [ 1.26785226],
#        [ 0.91488037],
#        [ 1.44683939],
#        [ 0.16172993],
#        [ 1.06926494],
#        [ 0.62179131],
#        [ 1.0776218 ],
#        [-0.7709864 ],
#        [ 1.02566911],
#        [-0.0293133 ],
#        [-0.53097208],
#        [ 0.49291964],
#        [ 0.24356531],
#        [ 0.96584991],
#        [-0.19326273],
#        [ 0.91029555],
#        [ 0.6410186 ],
#        [ 0.21605396],
#        [ 0.92358198],
#        [ 0.0243815 ],
#        [ 1.09805709],
#        [ 0.33869628],
#        [ 1.27799588],
#        [ 0.90223634],
#        [ 0.69625299],
#        [ 0.88215497],
#        [ 1.31344654],
#        [ 1.53980154],
#        [ 0.79419518],
#        [-0.32586514],
#        [-0.08938884],
#        [-0.2108868 ],
#        [ 0.11653087],
#        [ 1.3600876 ],
#        [ 0.56849174],
#        [ 0.78944915],
#        [ 1.20305302],
#        [ 0.7943564 ],
#        [ 0.22676318],
#        [ 0.14548423],
#        [ 0.44401218],
#        [ 0.87209731],
#        [ 0.21028347],
#        [-0.72660012],
#        [ 0.33676147],
#        [ 0.31278815],
#        [ 0.35677921],
#        [ 0.62372612],
#        [-0.92760343],
#        [ 0.27927231],
#        [ 2.51362245],
#        [ 1.39516536],
#        [ 2.59899587],
#        [ 1.95251737],
#        [ 2.33165373],
#        [ 3.37972129],
#        [ 0.49952523],
#        [ 2.91455996],
#        [ 2.301322  ],
#        [ 2.90125455],
#        [ 1.64426335],
#        [ 1.78400546],
#        [ 2.14768656],
#        [ 1.32538608],
#        [ 1.56638355],
#        [ 1.88686405],
#        [ 1.93129164],
#        [ 3.4724999 ],
#        [ 3.77710179],
#        [ 1.27920388],
#        [ 2.41070022],
#        [ 1.17912435],
#        [ 3.48199197],
#        [ 1.36935481],
#        [ 2.25831409],
#        [ 2.59703873],
#        [ 1.23933878],
#        [ 1.2724594 ],
#        [ 2.10450828],
#        [ 2.37028851],
#        [ 2.82355495],
#        [ 3.2164011 ],
#        [ 2.14037649],
#        [ 1.42488684],
#        [ 1.76088622],
#        [ 3.05957239],
#        [ 2.12711239],
#        [ 1.88690536],
#        [ 1.15056621],
#        [ 2.0901974 ],
#        [ 2.29653466],
#        [ 1.90504456],
#        [ 1.39516536],
#        [ 2.54569629],
#        [ 2.40178693],
#        [ 1.92627029],
#        [ 1.50709846],
#        [ 1.7461388 ],
#        [ 1.88372124],
#        [ 1.37119204]])

# %%
# explain more than 97% variance, need 2 principal components (pc1,pc2)
pca = PCA(n_components=2)  
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
# loading at each principal component
pca.components_
# Out:
# array([[ 0.36263433, -0.08122848,  0.85629752,  0.35868209],
#        [ 0.6558202 ,  0.73001455, -0.17703033, -0.07509244]])

# %%
pca.explained_variance_
# Out:
# array([4.20438706, 0.24314579])

# %%
# Apply PCA to the data set
data_pca = pca.transform(X)
data_pca
# Out:
# array([[-2.73363445, -0.16331092],
#        [-2.90803676, -0.13076902],
#        [-2.76491784, -0.30475856],
#        [-2.7461081 ,  0.34027983],
#        [-2.29679724,  0.75348469],
#        [-2.83904793, -0.0755604 ],
#        [-2.64423265,  0.17657389],
#        [-2.90682876, -0.56422248],
#        [-2.69199575, -0.10050325],
#        [-2.52354747,  0.65790634],
#        [-2.63112977,  0.02770681],
#        [-2.80576609, -0.2213837 ],
#        [-3.24397251, -0.4961847 ],
#        [-2.65975154,  1.19234788],
#        [-2.39988069,  1.3506441 ],
#        [-2.63931625,  0.82429682],
#        [-2.66585361,  0.32535115],
#        [-2.21575231,  0.88473854],
#        [-2.6045924 ,  0.52665249],
#        [-2.32791942,  0.4034959 ],
#        [-2.56060135,  0.44614179],
#        [-3.23368084,  0.14876388],
#        [-2.32098224,  0.11122065],
#        [-2.37424051, -0.02540228],
#        [-2.52611151, -0.13313497],
#        [-2.48686648,  0.14385237],
#        [-2.57982864,  0.38073938],
#        [-2.65733554,  0.32544096],
#        [-2.6511475 , -0.18387812],
#        [-2.60676122, -0.19129755],
#        [-2.42744251,  0.42388348],
#        [-2.66443393,  0.82625736],
#        [-2.61352803,  1.10619867],
#        [-2.69199575, -0.10050325],
#        [-2.88487621,  0.08368008],
#        [-2.64229784,  0.61289151],
#        [-2.69199575, -0.10050325],
#        [-3.00058136, -0.47351799],
#        [-2.60796922,  0.24215591],
#        [-2.7877468 ,  0.27747216],
#        [-2.87158978, -0.9264554 ],
#        [-3.01682706, -0.32751508],
#        [-2.42325291,  0.20183533],
#        [-2.22620519,  0.44833111],
#        [-2.73402967, -0.23640219],
#        [-2.55483086,  0.5164587 ],
#        [-2.85867044, -0.21405407],
#        [-2.5598109 ,  0.59232432],
#        [-2.72173956,  0.12127547],
#        [ 1.26785226,  0.6856034 ],
#        [ 0.91488037,  0.3200081 ],
#        [ 1.44683939,  0.50410462],
#        [ 0.16172993, -0.82370953],
#        [ 1.06926494,  0.07588127],
#        [ 0.62179131, -0.41605337],
#        [ 1.0776218 ,  0.28451223],
#        [-0.7709864 , -0.99775123],
#        [ 1.02566911,  0.22948323],
#        [-0.0293133 , -0.71825598],
#        [-0.53097208, -1.2595811 ],
#        [ 0.49291964, -0.10079581],
#        [ 0.24356531, -0.54627315],
#        [ 0.96584991, -0.12363915],
#        [-0.19326273, -0.24930664],
#        [ 0.91029555,  0.46896498],
#        [ 0.6410186 , -0.35065097],
#        [ 0.21605396, -0.33013295],
#        [ 0.92358198, -0.54117049],
#        [ 0.0243815 , -0.57940308],
#        [ 1.09805709, -0.08353883],
#        [ 0.33869628, -0.06521013],
#        [ 1.27799588, -0.32739624],
#        [ 0.90223634, -0.18162211],
#        [ 0.69625299,  0.15142829],
#        [ 0.88215497,  0.33038151],
#        [ 1.31344654,  0.24473051],
#        [ 1.53980154,  0.2672176 ],
#        [ 0.79419518, -0.16132435],
#        [-0.32586514, -0.36249822],
#        [-0.08938884, -0.70028352],
#        [-0.2108868 , -0.67507124],
#        [ 0.11653087, -0.30974537],
#        [ 1.3600876 , -0.4210547 ],
#        [ 0.56849174, -0.48181501],
#        [ 0.78944915,  0.19617369],
#        [ 1.20305302,  0.40834664],
#        [ 0.7943564 , -0.3698655 ],
#        [ 0.22676318, -0.26482035],
#        [ 0.14548423, -0.67770662],
#        [ 0.44401218, -0.66800805],
#        [ 0.87209731, -0.03293466],
#        [ 0.21028347, -0.40044986],
#        [-0.72660012, -1.00517067],
#        [ 0.33676147, -0.50152775],
#        [ 0.31278815, -0.20943212],
#        [ 0.35677921, -0.28994282],
#        [ 0.62372612,  0.02026425],
#        [-0.92760343, -0.74798588],
#        [ 0.27927231, -0.34524124],
#        [ 2.51362245, -0.0132104 ],
#        [ 1.39516536, -0.57474647],
#        [ 2.59899587,  0.34018141],
#        [ 1.95251737, -0.18183938],
#        [ 2.33165373, -0.04311693],
#        [ 3.37972129,  0.54417028],
#        [ 0.49952523, -1.18975088],
#        [ 2.91455996,  0.35005959],
#        [ 2.301322  , -0.24692319],
#        [ 2.90125455,  0.77832912],
#        [ 1.64426335,  0.2418257 ],
#        [ 1.78400546, -0.21666042],
#        [ 2.14768656,  0.21424748],
#        [ 1.32538608, -0.77613761],
#        [ 1.56638355, -0.53929124],
#        [ 1.88686405,  0.11830988],
#        [ 1.93129164,  0.04002915],
#        [ 3.4724999 ,  1.16855166],
#        [ 3.77710179,  0.24961889],
#        [ 1.27920388, -0.7608497 ],
#        [ 2.41070022,  0.37540785],
#        [ 1.17912435, -0.60501224],
#        [ 3.48199197,  0.4535556 ],
#        [ 1.36935481, -0.20392106],
#        [ 2.25831409,  0.33226376],
#        [ 2.59703873,  0.55659104],
#        [ 1.23933878, -0.17879859],
#        [ 1.2724594 , -0.11608073],
#        [ 2.10450828, -0.21178655],
#        [ 2.37028851,  0.46101268],
#        [ 2.82355495,  0.37053698],
#        [ 3.2164011 ,  1.36784329],
#        [ 2.14037649, -0.21929579],
#        [ 1.42488684, -0.14379794],
#        [ 1.76088622, -0.50197081],
#        [ 3.05957239,  0.68324898],
#        [ 2.12711239,  0.13811243],
#        [ 1.88690536,  0.04744858],
#        [ 1.15056621, -0.16395972],
#        [ 2.0901974 ,  0.37053399],
#        [ 2.29653466,  0.18143615],
#        [ 1.90504456,  0.4086246 ],
#        [ 1.39516536, -0.57474647],
#        [ 2.54569629,  0.27441977],
#        [ 2.40178693,  0.30222678],
#        [ 1.92627029,  0.18675607],
#        [ 1.50709846, -0.37513625],
#        [ 1.7461388 ,  0.07811976],
#        [ 1.88372124,  0.11544572],
#        [ 1.37119204, -0.28265084]])

# %%
df_pca=pd.DataFrame(data_pca, columns=['PC1','PC2'])

# %%
df_pca.corr()
# Out:
#               PC1           PC2
# PC1  1.000000e+00 -1.516508e-15
# PC2 -1.516508e-15  1.000000e+00

# %%
pca = PCA(n_components=3)
pca.fit(X)
# Out:
# PCA(n_components=3)

# %%
data_pca = pca.transform(X)
data_pca
# Out:
# array([[-2.73363445, -0.16331092, -0.20387761],
#        [-2.90803676, -0.13076902,  0.02432666],
#        [-2.76491784, -0.30475856,  0.03735406],
#        [-2.7461081 ,  0.34027983,  0.09572342],
#        [-2.29679724,  0.75348469,  0.17374038],
#        [-2.83904793, -0.0755604 ,  0.26385861],
#        [-2.64423265,  0.17657389, -0.01624978],
#        [-2.90682876, -0.56422248,  0.02708061],
#        [-2.69199575, -0.10050325, -0.19190446],
#        [-2.52354747,  0.65790634, -0.06985362],
#        [-2.63112977,  0.02770681,  0.10724693],
#        [-2.80576609, -0.2213837 , -0.200674  ],
#        [-3.24397251, -0.4961847 ,  0.0681067 ],
#        [-2.65975154,  1.19234788, -0.1452544 ],
#        [-2.39988069,  1.3506441 ,  0.28295963],
#        [-2.63931625,  0.82429682,  0.14467779],
#        [-2.66585361,  0.32535115,  0.03290039],
#        [-2.21575231,  0.88473854, -0.11513756],
#        [-2.6045924 ,  0.52665249,  0.21902432],
#        [-2.32791942,  0.4034959 , -0.2341806 ],
#        [-2.56060135,  0.44614179,  0.21431682],
#        [-3.23368084,  0.14876388,  0.29912295],
#        [-2.32098224,  0.11122065,  0.04528234],
#        [-2.37424051, -0.02540228,  0.12904387],
#        [-2.52611151, -0.13313497, -0.24746184],
#        [-2.48686648,  0.14385237,  0.10083972],
#        [-2.57982864,  0.38073938, -0.07286141],
#        [-2.65733554,  0.32544096, -0.13974649],
#        [-2.6511475 , -0.18387812,  0.0461236 ],
#        [-2.60676122, -0.19129755, -0.07161135],
#        [-2.42744251,  0.42388348, -0.13888805],
#        [-2.66443393,  0.82625736,  0.22994322],
#        [-2.61352803,  1.10619867,  0.16286234],
#        [-2.69199575, -0.10050325, -0.19190446],
#        [-2.88487621,  0.08368008, -0.15728558],
#        [-2.64229784,  0.61289151, -0.2617393 ],
#        [-2.69199575, -0.10050325, -0.19190446],
#        [-3.00058136, -0.47351799,  0.07943439],
#        [-2.60796922,  0.24215591, -0.07436531],
#        [-2.7877468 ,  0.27747216,  0.08375027],
#        [-2.87158978, -0.9264554 , -0.3411052 ],
#        [-3.01682706, -0.32751508,  0.19867324],
#        [-2.42325291,  0.20183533,  0.270283  ],
#        [-2.22620519,  0.44833111,  0.30299884],
#        [-2.73402967, -0.23640219, -0.09085015],
#        [-2.55483086,  0.5164587 ,  0.17137805],
#        [-2.85867044, -0.21405407,  0.08970783],
#        [-2.5598109 ,  0.59232432, -0.01173809],
#        [-2.72173956,  0.12127547, -0.08313486],
#        [ 1.26785226,  0.6856034 , -0.40635535],
#        [ 0.91488037,  0.3200081 , -0.01728155],
#        [ 1.44683939,  0.50410462, -0.33841603],
#        [ 0.16172993, -0.82370953, -0.17696872],
#        [ 1.06926494,  0.07588127, -0.30660914],
#        [ 0.62179131, -0.41605337,  0.0412256 ],
#        [ 1.0776218 ,  0.28451223,  0.16989663],
#        [-0.7709864 , -0.99775123,  0.01574857],
#        [ 1.02566911,  0.22948323, -0.41492909],
#        [-0.0293133 , -0.71825598,  0.28350185],
#        [-0.53097208, -1.2595811 , -0.26631337],
#        [ 0.49291964, -0.10079581,  0.1322603 ],
#        [ 0.24356531, -0.54627315, -0.69190157],
#        [ 0.96584991, -0.12363915, -0.06217387],
#        [-0.19326273, -0.24930664,  0.09356972],
#        [ 0.91029555,  0.46896498, -0.31342514],
#        [ 0.6410186 , -0.35065097,  0.32840383],
#        [ 0.21605396, -0.33013295, -0.27030773],
#        [ 0.92358198, -0.54117049, -0.49724476],
#        [ 0.0243815 , -0.57940308, -0.2329349 ],
#        [ 1.09805709, -0.08353883,  0.45982882],
#        [ 0.33869628, -0.06521013, -0.22756476],
#        [ 1.27799588, -0.32739624, -0.34743941],
#        [ 0.90223634, -0.18162211, -0.23161715],
#        [ 0.69625299,  0.15142829, -0.32049498],
#        [ 0.88215497,  0.33038151, -0.31492903],
#        [ 1.31344654,  0.24473051, -0.52133635],
#        [ 1.53980154,  0.2672176 , -0.16471489],
#        [ 0.79419518, -0.16132435,  0.03632229],
#        [-0.32586514, -0.36249822, -0.31540552],
#        [-0.08938884, -0.70028352, -0.24170444],
#        [-0.2108868 , -0.67507124, -0.30388202],
#        [ 0.11653087, -0.30974537, -0.17501518],
#        [ 1.3600876 , -0.4210547 ,  0.01558925],
#        [ 0.56849174, -0.48181501,  0.44463489],
#        [ 0.78944915,  0.19617369,  0.38933135],
#        [ 1.20305302,  0.40834664, -0.23671627],
#        [ 0.7943564 , -0.3698655 , -0.61283036],
#        [ 0.22676318, -0.26482035,  0.18951739],
#        [ 0.14548423, -0.67770662, -0.05772987],
#        [ 0.44401218, -0.66800805, -0.02395977],
#        [ 0.87209731, -0.03293466, -0.00982009],
#        [ 0.21028347, -0.40044986, -0.22736895],
#        [-0.72660012, -1.00517067, -0.10198639],
#        [ 0.33676147, -0.50152775,  0.01792476],
#        [ 0.31278815, -0.20943212,  0.08375558],
#        [ 0.35677921, -0.28994282,  0.07904808],
#        [ 0.62372612,  0.02026425, -0.20426392],
#        [-0.92760343, -0.74798588, -0.00774809],
#        [ 0.27927231, -0.34524124,  0.012163  ],
#        [ 2.51362245, -0.0132104 ,  0.7585574 ],
#        [ 1.39516536, -0.57474647,  0.29655609],
#        [ 2.59899587,  0.34018141, -0.11213847],
#        [ 1.95251737, -0.18183938,  0.10663361],
#        [ 2.33165373, -0.04311693,  0.28420098],
#        [ 3.37972129,  0.54417028, -0.35185658],
#        [ 0.49952523, -1.18975088,  0.54693926],
#        [ 2.91455996,  0.35005959, -0.42366214],
#        [ 2.301322  , -0.24692319, -0.34977491],
#        [ 2.90125455,  0.77832912,  0.42164156],
#        [ 1.64426335,  0.2418257 ,  0.24275644],
#        [ 1.78400546, -0.21666042, -0.03760579],
#        [ 2.14768656,  0.21424748,  0.03314552],
#        [ 1.32538608, -0.77613761,  0.28307904],
#        [ 1.56638355, -0.53929124,  0.63073514],
#        [ 1.88686405,  0.11830988,  0.48013905],
#        [ 1.93129164,  0.04002915,  0.04275633],
#        [ 3.4724999 ,  1.16855166,  0.12916088],
#        [ 3.77710179,  0.24961889, -0.51682901],
#        [ 1.27920388, -0.7608497 , -0.34468545],
#        [ 2.41070022,  0.37540785,  0.21862399],
#        [ 1.17912435, -0.60501224,  0.5127872 ],
#        [ 3.48199197,  0.4535556 , -0.57685723],
#        [ 1.36935481, -0.20392106, -0.06346478],
#        [ 2.25831409,  0.33226376,  0.28465063],
#        [ 2.59703873,  0.55659104, -0.20848527],
#        [ 1.23933878, -0.17879859,  0.04700453],
#        [ 1.2724594 , -0.11608073,  0.23162456],
#        [ 2.10450828, -0.21178655,  0.15363444],
#        [ 2.37028851,  0.46101268, -0.45207928],
#        [ 2.82355495,  0.37053698, -0.50101647],
#        [ 3.2164011 ,  1.36784329, -0.11869097],
#        [ 2.14037649, -0.21929579,  0.20854636],
#        [ 1.42488684, -0.14379794, -0.15404983],
#        [ 1.76088622, -0.50197081, -0.17564131],
#        [ 3.05957239,  0.68324898, -0.3364765 ],
#        [ 2.12711239,  0.13811243,  0.7342023 ],
#        [ 1.88690536,  0.04744858,  0.16049129],
#        [ 1.15056621, -0.16395972,  0.28247444],
#        [ 2.0901974 ,  0.37053399,  0.02738377],
#        [ 2.29653466,  0.18143615,  0.3228819 ],
#        [ 1.90504456,  0.4086246 ,  0.11541067],
#        [ 1.39516536, -0.57474647,  0.29655609],
#        [ 2.54569629,  0.27441977,  0.29127082],
#        [ 2.40178693,  0.30222678,  0.50429833],
#        [ 1.92627029,  0.18675607,  0.17928796],
#        [ 1.50709846, -0.37513625, -0.12052606],
#        [ 1.7461388 ,  0.07811976,  0.13078324],
#        [ 1.88372124,  0.11544572,  0.72287461],
#        [ 1.37119204, -0.28265084,  0.36238691]])

# %%
df_pca=pd.DataFrame(data_pca, columns=['PC1','PC2','PC3'])

# %%
df_pca.corr()
# Out:
#               PC1           PC2           PC3
# PC1  1.000000e+00 -1.516508e-15 -4.124791e-16
# PC2 -1.516508e-15  1.000000e+00  5.485189e-16
# PC3 -4.124791e-16  5.485189e-16  1.000000e+00

# %%
pca.components_
# Out:
# array([[ 0.36263433, -0.08122848,  0.85629752,  0.35868209],
#        [ 0.6558202 ,  0.73001455, -0.17703033, -0.07509244],
#        [-0.58115529,  0.59619427,  0.07265649,  0.54911925]])

# %%
pca.explained_variance_
# Out:
# array([4.20438706, 0.24314579, 0.07905128])
